# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pprint import pprint
from sqlalchemy import create_engine
from keys import sqlkey

# %%
toptv = pd.read_csv ('Resources/National Hispanic Black Ratings Week of September 14 2020.csv') 
ratings_df = pd.DataFrame(toptv, columns= ['RANK', 'PROGRAM','NETWORK', 'RATING', 'VIEWERS','Sample'])
ratings_df
# Out:
#     RANK                    PROGRAM NETWORK  RATING VIEWERS            Sample
# 0      1  NBC SUNDAY NIGHT FOOTBALL     NBC    10.0  17,689          National
# 1      2  SUNDAY NIGHT NFL PRE-KICK     NBC     6.4  11,506          National
# 2      3  FOX NFL SUNDAY-PST GN-NAT     FOX     5.9  10,883          National
# 3      4                 60 MINUTES     CBS     5.7   9,662          National
# 4      5     DANCING WITH THE STARS     ABC     5.1   8,132          National
# 5      6   FOOTBALL NT AMERICA PT 3     NBC     4.8   8,430          National
# 6      7                 ACM AWARDS     CBS     4.1   6,835          National
# 7      8      PRIMETIME EMMY AWARDS     ABC     4.0   6,360          National
# 8      9   AMERICA'S GOT TALENT-TUE     NBC     3.5   5,945          National
# 9     10   AMERICA'S GOT TALENT-WED     NBC     3.3   5,330          National
# 10     1    QUIEN ES LA MASCARA SUN     UNI     6.8    1980          Hispanic
# ...

# %%
engine = create_engine('postgresql://postgres:'+sqlkey+'@localhost:5432/ETL')
connection = engine.connect()

# %%
ratings_df.to_sql(name='tvshows', con=connection, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "VIEWERS" of relation "tvshows" does not exist
# LINE 1: ... tvshows ("RANK", "PROGRAM", "NETWORK", "RATING", "VIEWERS",...
#                                                              ^
#
#
# ...
