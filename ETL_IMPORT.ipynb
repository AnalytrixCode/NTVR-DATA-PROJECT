# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pprint import pprint
from sqlalchemy import create_engine
from keys import sqlkey

# %%
toptv = pd.read_csv ('Resources/National Hispanic Black Ratings Week of September 14 2020.csv') 
toptv
# Out:
#     RANK                    PROGRAM NETWORK  RATING VIEWERS (000)  \
# 0      1  NBC SUNDAY NIGHT FOOTBALL     NBC    10.0        17,689
# 1      2  SUNDAY NIGHT NFL PRE-KICK     NBC     6.4        11,506
# 2      3  FOX NFL SUNDAY-PST GN-NAT     FOX     5.9        10,883
# 3      4                 60 MINUTES     CBS     5.7         9,662
# 4      5     DANCING WITH THE STARS     ABC     5.1         8,132
# 5      6   FOOTBALL NT AMERICA PT 3     NBC     4.8         8,430
# 6      7                 ACM AWARDS     CBS     4.1         6,835
# 7      8      PRIMETIME EMMY AWARDS     ABC     4.0         6,360
# 8      9   AMERICA'S GOT TALENT-TUE     NBC     3.5         5,945
# 9     10   AMERICA'S GOT TALENT-WED     NBC     3.3         5,330
# 10     1    QUIEN ES LA MASCARA SUN     UNI     6.8          1980
# 11     2  MEDICOS LINEA DE VIDA WED     UNI     5.8          1510
# 12     3  MEDICOS LINEA DE VIDA MON     UNI     5.4          1462
# ...

# %%
engine = create_engine('postgresql://postgres:'+sqlkey+'@localhost:5432/ETL')
connection = engine.connect()

# %%
toptv.to_sql(name='tvshows', con=connection, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-367e712dde3e> in <module>
# ----> 1 toptv.to_sql(name='tvshows', con=connection, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ...
